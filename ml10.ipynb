# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv(r'C:\Users\Lenovo\Downloads\archive (3)\flight_data_BOM_BLR.csv')

# %%
df1
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Air India     AI 621        Mumbai         03:55    Bengaluru
# 1     AirAsia     I5 670        Mumbai         19:55    Bengaluru
# 2     AirAsia    I5 2992        Mumbai         23:55    Bengaluru
# 3      IndiGo    6E 5388        Mumbai         21:30    Bengaluru
# 4   Akasa Air    QP 1103        Mumbai         00:45    Bengaluru
# ..        ...        ...           ...           ...          ...
# 85    Vistara     UK 840     Bengaluru         21:35       Mumbai
# 86    Vistara     UK 850     Bengaluru         19:55       Mumbai
# 87    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 88    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 89  Air India     AI 642     Bengaluru         21:25       Mumbai
#
#         ArrivingTime   Duration   Price
# 0              05:50  01 h 55 m   2,307
# 1              21:45  01 h 50 m   2,773
# 2   01:45\r\n+ 1 DAY  01 h 50 m   2,773
# ...

# %%
df2=pd.read_csv(r'C:\Users\Lenovo\Downloads\archive (3)\flight_data_DEL_BLR.csv')

# %%
df2
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Akasa Air    QP 1409     New Delhi         23:00    Bengaluru
# 1     AirAsia     I5 740     New Delhi         07:50    Bengaluru
# 2     AirAsia    I5 1534     New Delhi         22:55    Bengaluru
# 3      IndiGo    6E 2067     New Delhi         03:55    Bengaluru
# 4      IndiGo    6E 6612     New Delhi         05:50    Bengaluru
# ..        ...        ...           ...           ...          ...
# 90  Air India     AI 808     Bengaluru         21:00    New Delhi
# 91    Vistara     UK 816     Bengaluru         11:30    New Delhi
# 92    Vistara     UK 816     Bengaluru         11:30    New Delhi
# 93     IndiGo    6E 2339     Bengaluru         00:30    New Delhi
# 94    Vistara     UK 808     Bengaluru         08:00    New Delhi
#
#       ArrivingTime   Duration   Price
# 0   01:45\n+ 1 DAY  02 h 45 m   5,230
# 1            10:40  02 h 50 m   5,235
# 2   01:35\n+ 1 DAY  02 h 40 m   5,235
# ...

# %%
df3=pd.read_csv(r'C:\Users\Lenovo\Downloads\archive (3)\flight_data_DEL_BOM.csv')

# %%
df3
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Akasa Air    QP 1719     New Delhi         09:00       Mumbai
# 1   Akasa Air    QP 1411     New Delhi         10:55       Mumbai
# 2   Akasa Air    QP 1128     New Delhi         16:00       Mumbai
# 3      IndiGo    6E 2009     New Delhi         01:00       Mumbai
# 4      IndiGo    6E 2112     New Delhi         05:30       Mumbai
# ..        ...        ...           ...           ...          ...
# 95    Vistara     UK 902        Mumbai         15:45    New Delhi
# 96    Vistara     UK 910        Mumbai         17:25    New Delhi
# 97    Vistara     UK 996        Mumbai         18:30    New Delhi
# 98    Vistara     UK 950        Mumbai         21:55    New Delhi
# 99    Vistara     UK 986        Mumbai         22:50    New Delhi
#
#       ArrivingTime   Duration   Price
# 0            10:55  01 h 55 m   4,758
# 1            13:05  02 h 10 m   4,758
# 2            18:10  02 h 10 m   4,758
# ...

# %% [markdown]
# df3

# %%
df4=pd.read_csv(r'C:\Users\Lenovo\Downloads\archive (3)\flight_data_DEL_CCU.csv')

# %%
df4
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0      IndiGo    6E 2284     New Delhi         05:25      Kolkata
# 1     Vistara     UK 747     New Delhi         06:15      Kolkata
# 2      IndiGo    6E 5219     New Delhi         06:25      Kolkata
# 3      IndiGo    6E 6182     New Delhi         15:55      Kolkata
# 4      IndiGo    6E 2415     New Delhi         17:45      Kolkata
# 5      IndiGo    6E 2415     New Delhi         17:45      Kolkata
# 6      IndiGo    6E 2415     New Delhi         17:45      Kolkata
# 7      IndiGo    6E 2057     New Delhi         19:00      Kolkata
# 8      IndiGo    6E 2057     New Delhi         19:00      Kolkata
# 9    SpiceJet    SG 8251     New Delhi         19:30      Kolkata
# 10     IndiGo    6E 2517     New Delhi         20:30      Kolkata
# 11     IndiGo    6E 6005     New Delhi         22:50      Kolkata
# 12     IndiGo    6E 2603     New Delhi         23:50      Kolkata
# ...

# %%
df5=pd.read_csv(r'C:\Users\Lenovo\Downloads\archive (3)\flight_data_DEL_HYD.csv')

# %%
df5
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Akasa Air    QP 1406     New Delhi         12:45    Hyderabad
# 1      IndiGo    6E 2461     New Delhi         01:55    Hyderabad
# 2      IndiGo    6E 2337     New Delhi         05:40    Hyderabad
# 3      IndiGo    6E 6203     New Delhi         06:30    Hyderabad
# 4   Air India     AI 560     New Delhi         07:10    Hyderabad
# 5   Air India     AI 560     New Delhi         07:10    Hyderabad
# 6   Air India     AI 560     New Delhi         07:10    Hyderabad
# 7      IndiGo     6E 774     New Delhi         08:10    Hyderabad
# 8      IndiGo     6E 774     New Delhi         08:10    Hyderabad
# 9   Air India     AI 542     New Delhi         09:30    Hyderabad
# 10     IndiGo    6E 2005     New Delhi         10:10    Hyderabad
# 11  Air India     AI 522     New Delhi         11:05    Hyderabad
# 12     IndiGo     6E 837     New Delhi         13:30    Hyderabad
# ...

# %%
df=pd.concat([df1,df2,df3,df4,df5],axis=0)

# %%
df
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Air India     AI 621        Mumbai         03:55    Bengaluru
# 1     AirAsia     I5 670        Mumbai         19:55    Bengaluru
# 2     AirAsia    I5 2992        Mumbai         23:55    Bengaluru
# 3      IndiGo    6E 5388        Mumbai         21:30    Bengaluru
# 4   Akasa Air    QP 1103        Mumbai         00:45    Bengaluru
# ..        ...        ...           ...           ...          ...
# 54   SpiceJet     SG 160     Hyderabad         06:10    New Delhi
# 55    Vistara     UK 830     Hyderabad         10:10    New Delhi
# 56    Vistara     UK 830     Hyderabad         10:10    New Delhi
# 57    Vistara     UK 860     Hyderabad         07:00    New Delhi
# 58    Vistara     UK 870     Hyderabad         20:35    New Delhi
#
#         ArrivingTime   Duration  Price
# 0              05:50  01 h 55 m  2,307
# 1              21:45  01 h 50 m  2,773
# 2   01:45\r\n+ 1 DAY  01 h 50 m  2,773
# ...

# %%
((df.isnull().sum())/len(df))*100
# Out:
# FlightName       0.0
# FlightCode       0.0
# DepartingCity    0.0
# DepartingTime    0.0
# ArrivingCity     0.0
# ArrivingTime     0.0
# Duration         0.0
# Price            0.0
# dtype: float64

# %%
df.ArrivingTime.value_counts()
# Out:
# 08:35             7
# 14:05             7
# 12:30             7
# 20:35             6
# 01:00\n+ 1 DAY    6
#                  ..
# 08:20             1
# 03:00             1
# 11:25             1
# 13:05             1
# 05:50             1
# Name: ArrivingTime, Length: 184, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FlightName     404 non-null    object
#  1   FlightCode     404 non-null    object
#  2   DepartingCity  404 non-null    object
#  3   DepartingTime  404 non-null    object
#  4   ArrivingCity   404 non-null    object
#  5   ArrivingTime   404 non-null    object
#  6   Duration       404 non-null    object
#  7   Price          404 non-null    object
# dtypes: object(8)
# memory usage: 28.4+ KB

# %%
df['Price'] =df['Price'].str.replace(',','').astype('Int64')

# %%
df
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Air India     AI 621        Mumbai         03:55    Bengaluru
# 1     AirAsia     I5 670        Mumbai         19:55    Bengaluru
# 2     AirAsia    I5 2992        Mumbai         23:55    Bengaluru
# 3      IndiGo    6E 5388        Mumbai         21:30    Bengaluru
# 4   Akasa Air    QP 1103        Mumbai         00:45    Bengaluru
# ..        ...        ...           ...           ...          ...
# 54   SpiceJet     SG 160     Hyderabad         06:10    New Delhi
# 55    Vistara     UK 830     Hyderabad         10:10    New Delhi
# 56    Vistara     UK 830     Hyderabad         10:10    New Delhi
# 57    Vistara     UK 860     Hyderabad         07:00    New Delhi
# 58    Vistara     UK 870     Hyderabad         20:35    New Delhi
#
#         ArrivingTime   Duration  Price
# 0              05:50  01 h 55 m   2307
# 1              21:45  01 h 50 m   2773
# 2   01:45\r\n+ 1 DAY  01 h 50 m   2773
# ...

# %%
((df.isnull().sum())/len(df))*100
# Out:
# FlightName       0.0
# FlightCode       0.0
# DepartingCity    0.0
# DepartingTime    0.0
# ArrivingCity     0.0
# ArrivingTime     0.0
# Duration         0.0
# Price            0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FlightName     404 non-null    object
#  1   FlightCode     404 non-null    object
#  2   DepartingCity  404 non-null    object
#  3   DepartingTime  404 non-null    object
#  4   ArrivingCity   404 non-null    object
#  5   ArrivingTime   404 non-null    object
#  6   Duration       404 non-null    object
#  7   Price          404 non-null    Int64
# dtypes: Int64(1), object(7)
# memory usage: 28.8+ KB

# %%
time_split=df['DepartingTime'] =df['DepartingTime'].str.split(':')

# %%
hr=time_split.str[0].astype(int)
minu=time_split.str[1].astype(int)

# %%
df['DepartTime']=hr+minu/60.0

# %%
df.drop('DepartingTime',axis=1,inplace=True)

# %%
df
# Out:
#    FlightName FlightCode DepartingCity ArrivingCity      ArrivingTime  \
# 0   Air India     AI 621        Mumbai    Bengaluru             05:50
# 1     AirAsia     I5 670        Mumbai    Bengaluru             21:45
# 2     AirAsia    I5 2992        Mumbai    Bengaluru  01:45\r\n+ 1 DAY
# 3      IndiGo    6E 5388        Mumbai    Bengaluru             23:15
# 4   Akasa Air    QP 1103        Mumbai    Bengaluru             02:20
# ..        ...        ...           ...          ...               ...
# 54   SpiceJet     SG 160     Hyderabad    New Delhi             08:25
# 55    Vistara     UK 830     Hyderabad    New Delhi             12:30
# 56    Vistara     UK 830     Hyderabad    New Delhi             12:30
# 57    Vistara     UK 860     Hyderabad    New Delhi             08:55
# 58    Vistara     UK 870     Hyderabad    New Delhi             22:45
#
#      Duration  Price  DepartTime
# 0   01 h 55 m   2307    3.916667
# 1   01 h 50 m   2773   19.916667
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FlightName     404 non-null    object
#  1   FlightCode     404 non-null    object
#  2   DepartingCity  404 non-null    object
#  3   ArrivingCity   404 non-null    object
#  4   ArrivingTime   404 non-null    object
#  5   Duration       404 non-null    object
#  6   Price          404 non-null    Int64
#  7   DepartTime     404 non-null    float64
# dtypes: Int64(1), float64(1), object(6)
# memory usage: 28.8+ KB

# %%
df=df.reset_index(drop=True)

# %%
pd.set_option('display.max_columns',None,'display.max_rows',None)

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity      ArrivingTime  \
# 0    Air India     AI 621        Mumbai    Bengaluru             05:50
# 1      AirAsia     I5 670        Mumbai    Bengaluru             21:45
# 2      AirAsia    I5 2992        Mumbai    Bengaluru  01:45\r\n+ 1 DAY
# 3       IndiGo    6E 5388        Mumbai    Bengaluru             23:15
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru             02:20
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru             02:20
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru             02:20
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru             21:35
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru             21:35
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru             19:40
# 10      IndiGo    6E 6953        Mumbai    Bengaluru             02:40
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru             20:35
# ...

# %%
df=df.drop([2,19,20,55,90,92,100,101,105,106,107,108,166,221,222,223,224,234,264,265,266,267,283,284,296,297,322,323,324,325,372,384,385])

# %%
df.shape
# Out:
# (371, 8)

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity ArrivingTime   Duration  \
# 0    Air India     AI 621        Mumbai    Bengaluru        05:50  01 h 55 m
# 1      AirAsia     I5 670        Mumbai    Bengaluru        21:45  01 h 50 m
# 3       IndiGo    6E 5388        Mumbai    Bengaluru        23:15  01 h 45 m
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru        02:20  01 h 35 m
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru        02:20  01 h 35 m
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru        02:20  01 h 35 m
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru        21:35  01 h 35 m
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru        21:35  01 h 35 m
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru        19:40  01 h 35 m
# 10      IndiGo    6E 6953        Mumbai    Bengaluru        02:40  01 h 50 m
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru        20:35  01 h 35 m
# ...

# %%
timeSplit=df['ArrivingTime'] =df['ArrivingTime'].str.split(':')

# %%
hr=timeSplit.str[0].astype(int)
minu=timeSplit.str[1].astype(int)

# %%
df['ArriveTime']=hr+minu/60.0

# %%
df.drop('ArrivingTime',axis=1,inplace=True)

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity   Duration  Price  \
# 0    Air India     AI 621        Mumbai    Bengaluru  01 h 55 m   2307
# 1      AirAsia     I5 670        Mumbai    Bengaluru  01 h 50 m   2773
# 3       IndiGo    6E 5388        Mumbai    Bengaluru  01 h 45 m   2839
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru  01 h 35 m   3005
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru  01 h 35 m   3005
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru  01 h 35 m   3005
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru  01 h 35 m   3005
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru  01 h 35 m   3005
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru  01 h 35 m   3053
# 10      IndiGo    6E 6953        Mumbai    Bengaluru  01 h 50 m   3219
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru  01 h 35 m   3283
# 12      IndiGo    6E 5352        Mumbai    Bengaluru  01 h 40 m   3420
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 0 to 403
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FlightName     371 non-null    object
#  1   FlightCode     371 non-null    object
#  2   DepartingCity  371 non-null    object
#  3   ArrivingCity   371 non-null    object
#  4   Duration       371 non-null    object
#  5   Price          371 non-null    Int64
#  6   DepartTime     371 non-null    float64
#  7   ArriveTime     371 non-null    float64
# dtypes: Int64(1), float64(2), object(5)
# memory usage: 26.4+ KB

# %%
TimeSplit=df['Duration'].str.split(' ')

# %%
TimeSplit
# Out:
# 0      [01, h, 55, m]
# 1      [01, h, 50, m]
# 3      [01, h, 45, m]
# 4      [01, h, 35, m]
# 5      [01, h, 35, m]
# 6      [01, h, 35, m]
# 7      [01, h, 35, m]
# 8      [01, h, 35, m]
# 9      [01, h, 35, m]
# 10     [01, h, 50, m]
# 11     [01, h, 35, m]
# 12     [01, h, 40, m]
# 13     [01, h, 45, m]
# 14     [01, h, 45, m]
# 15     [01, h, 45, m]
# 16     [01, h, 45, m]
# 17     [01, h, 45, m]
# 18     [01, h, 45, m]
# 21     [01, h, 40, m]
# 22     [01, h, 50, m]
# 23     [01, h, 45, m]
# 24     [01, h, 45, m]
# 25     [01, h, 35, m]
# 26     [01, h, 35, m]
# 27     [01, h, 55, m]
# 28     [01, h, 30, m]
# 29            [02, h]
# 30     [01, h, 50, m]
# 31     [01, h, 50, m]
# 32     [01, h, 50, m]
# 33     [01, h, 30, m]
# 34     [01, h, 45, m]
# 35     [01, h, 45, m]
# 36     [01, h, 55, m]
# 37     [01, h, 45, m]
# 38     [01, h, 45, m]
# 39     [01, h, 40, m]
# 40     [01, h, 55, m]
# 41     [01, h, 45, m]
# 42     [01, h, 50, m]
# 43     [01, h, 50, m]
# ...

# %%
hour=TimeSplit.str[0].astype(int)

# %%
df['Duration']=hour

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity  Duration  Price  \
# 0    Air India     AI 621        Mumbai    Bengaluru         1   2307
# 1      AirAsia     I5 670        Mumbai    Bengaluru         1   2773
# 3       IndiGo    6E 5388        Mumbai    Bengaluru         1   2839
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru         1   3053
# 10      IndiGo    6E 6953        Mumbai    Bengaluru         1   3219
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru         1   3283
# 12      IndiGo    6E 5352        Mumbai    Bengaluru         1   3420
# ...

# %%
((df.isnull().sum())/len(df))*100
# Out:
# FlightName       0.0
# FlightCode       0.0
# DepartingCity    0.0
# ArrivingCity     0.0
# Duration         0.0
# Price            0.0
# DepartTime       0.0
# ArriveTime       0.0
# dtype: float64

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity  Duration  Price  \
# 0    Air India     AI 621        Mumbai    Bengaluru         1   2307
# 1      AirAsia     I5 670        Mumbai    Bengaluru         1   2773
# 3       IndiGo    6E 5388        Mumbai    Bengaluru         1   2839
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru         1   3053
# 10      IndiGo    6E 6953        Mumbai    Bengaluru         1   3219
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru         1   3283
# 12      IndiGo    6E 5352        Mumbai    Bengaluru         1   3420
# ...

# %%
split_data=df['FlightCode'].str.split(' ',expand=True)

# %%
df['Code']=split_data[1]

# %%
df
# Out:
#     FlightName FlightCode DepartingCity ArrivingCity  Duration  Price  \
# 0    Air India     AI 621        Mumbai    Bengaluru         1   2307
# 1      AirAsia     I5 670        Mumbai    Bengaluru         1   2773
# 3       IndiGo    6E 5388        Mumbai    Bengaluru         1   2839
# 4    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 5    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 6    Akasa Air    QP 1103        Mumbai    Bengaluru         1   3005
# 7    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 8    Akasa Air    QP 1341        Mumbai    Bengaluru         1   3005
# 9    Akasa Air    QP 1139        Mumbai    Bengaluru         1   3053
# 10      IndiGo    6E 6953        Mumbai    Bengaluru         1   3219
# 11   Akasa Air    QP 1306        Mumbai    Bengaluru         1   3283
# 12      IndiGo    6E 5352        Mumbai    Bengaluru         1   3420
# ...

# %%
df.drop('FlightCode',axis=1,inplace=True)

# %%
df['Code']=df['Code'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 0 to 403
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FlightName     371 non-null    object
#  1   DepartingCity  371 non-null    object
#  2   ArrivingCity   371 non-null    object
#  3   Duration       371 non-null    int32
#  4   Price          371 non-null    Int64
#  5   DepartTime     371 non-null    float64
#  6   ArriveTime     371 non-null    float64
#  7   Code           371 non-null    int32
# dtypes: Int64(1), float64(2), int32(2), object(3)
# memory usage: 23.5+ KB

# %%
status = pd.get_dummies(df[['FlightName','DepartingCity','ArrivingCity']],drop_first=True)

# %%
df=pd.concat([df,status],axis=1)

# %%
df.drop(['FlightName','DepartingCity','ArrivingCity'],axis=1,inplace=True)

# %%
df
# Out:
#      Duration  Price  DepartTime  ArriveTime  Code  FlightName_AirAsia  \
# 0           1   2307    3.916667    5.833333   621                   0
# 1           1   2773   19.916667   21.750000   670                   1
# 3           1   2839   21.500000   23.250000  5388                   0
# 4           1   3005    0.750000    2.333333  1103                   0
# 5           1   3005    0.750000    2.333333  1103                   0
# 6           1   3005    0.750000    2.333333  1103                   0
# 7           1   3005   20.000000   21.583333  1341                   0
# 8           1   3005   20.000000   21.583333  1341                   0
# 9           1   3053   18.083333   19.666667  1139                   0
# 10          1   3219    0.833333    2.666667  6953                   0
# 11          1   3283   19.000000   20.583333  1306                   0
# 12          1   3420    6.166667    7.833333  5352                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371 entries, 0 to 403
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Duration                 371 non-null    int32
#  1   Price                    371 non-null    Int64
#  2   DepartTime               371 non-null    float64
#  3   ArriveTime               371 non-null    float64
#  4   Code                     371 non-null    int32
#  5   FlightName_AirAsia       371 non-null    uint8
#  6   FlightName_Akasa Air     371 non-null    uint8
#  7   FlightName_IndiGo        371 non-null    uint8
#  8   FlightName_SpiceJet      371 non-null    uint8
#  9   FlightName_Vistara       371 non-null    uint8
#  10  DepartingCity_Hyderabad  371 non-null    uint8
#  11  DepartingCity_Kolkata    371 non-null    uint8
#  12  DepartingCity_Mumbai     371 non-null    uint8
#  13  DepartingCity_New Delhi  371 non-null    uint8
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %%
df.drop(['DepartTime','ArrivingCity_New Delhi'],axis=1,inplace=True)

# %%
X=df.drop(['Price'],axis=1)
y=df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
from sklearn.svm import SVR

# %%
svm_regression=SVR(kernel='linear',C=100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
svm_regression.fit(X_train,y_train)
# Out:
# SVR(C=100, kernel='linear')

# %%
print(svm_regression.intercept_)
print(svm_regression.coef_)
# Out:
# [5619.09595949]
# [[-7.72279220e+00  4.82858689e-01 -3.03876953e-01 -2.61524338e+02
#   -2.35231189e+02 -8.39765690e+01 -1.54455844e+01  4.52040920e+02
#   -3.21237294e+02  4.47534757e+02 -6.35231189e+02 -1.14096352e+02
#   -6.67396941e+02 -9.39303874e+00 -6.37306372e+02]]

# %%
y_pred=svm_regression.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
r_squared=r2_score(y_test,y_pred)

# %%
r_squared
# Out:
# 0.032086827099527815
